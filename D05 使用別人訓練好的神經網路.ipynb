# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
from keras.applications.vgg19 import VGG19
from keras.preprocessing import image
from keras.applications.vgg19 import preprocess_input
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %%
base_model = VGG19(weights='imagenet')
model = Model(inputs=base_model.input, outputs=base_model.get_layer('block4_pool').output)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574676992/574710816 [============================>.] - ETA: 0s
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-2-46f7d5295cbb> in <module>()
# ----> 1 base_model = VGG19(weights='imagenet')
#       2 model = Model(inputs=base_model.input, outputs=base_model.get_layer('block4_pool').output)
#
# /home/yenlung/anaconda3/lib/python3.6/site-packages/keras/applications/vgg19.py in VGG19(include_top, weights, input_tensor, input_shape, pooling, classes)
#     170                                     WEIGHTS_PATH_NO_TOP,
#     171                                     cache_subdir='models')
# --> 172         model.load_weights(weights_path)
#     173         if K.backend() == 'theano':
#     174             layer_utils.convert_all_kernels_in_model(model)
#
# /home/yenlung/anaconda3/lib/python3.6/site-packages/keras/engine/topology.py in load_weights(self, filepath, by_name)
#    2570             load_weights_from_hdf5_group_by_name(f, self.layers)
#    2571         else:
# -> 2572             load_weights_from_hdf5_group(f, self.layers)
#    2573
#    2574         if hasattr(f, 'close'):
#
# /home/yenlung/anaconda3/lib/python3.6/site-packages/keras/engine/topology.py in load_weights_from_hdf5_group(f, layers)
#    3006                              ' elements.')
#    3007         weight_value_tuples += zip(symbolic_weights, weight_values)
# -> 3008     K.batch_set_value(weight_value_tuples)
#    3009
#    3010
#
# /home/yenlung/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in batch_set_value(tuples)
#    2187             assign_ops.append(assign_op)
#    2188             feed_dict[assign_placeholder] = value
# -> 2189         get_session().run(assign_ops, feed_dict=feed_dict)
#    2190
#    2191
#
# /home/yenlung/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     161                 config = tf.ConfigProto(intra_op_parallelism_threads=num_thread,
#     162                                         allow_soft_placement=True)
# --> 163             _SESSION = tf.Session(config=config)
#     164         session = _SESSION
#     165     if not _MANUAL_VAR_INIT:
#
# /home/yenlung/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __init__(self, target, graph, config)
#    1290
#    1291     """
# -> 1292     super(Session, self).__init__(target, graph, config=config)
#    1293     # NOTE(mrry): Create these on first `__enter__` to avoid a reference cycle.
#    1294     self._default_graph_context_manager = None
#
# /home/yenlung/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __init__(self, target, graph, config)
#     560     try:
#     561       with errors.raise_exception_on_not_ok_status() as status:
# --> 562         self._session = tf_session.TF_NewDeprecatedSession(opts, status)
#     563     finally:
#     564       tf_session.TF_DeleteSessionOptions(opts)
#
# /home/yenlung/anaconda3/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      87         if type is None:
#      88             try:
# ---> 89                 next(self.gen)
#      90             except StopIteration:
#      91                 return
#
# /home/yenlung/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     464           None, None,
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#     468     pywrap_tensorflow.TF_DeleteStatus(status)
#
# InternalError: Failed to create session.

# %% [markdown]
# ![bird](bird01.jpg)

# %%
img_path = 'bird01.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
block4_pool_features = model.predict(x)

# %%
plt.imshow(block4_pool_features[0,:,:,2])

# %%
x = image.img_to_array(img)

# %%
block4_pool_features[0][3].shape
# Out:
# (14, 512)
