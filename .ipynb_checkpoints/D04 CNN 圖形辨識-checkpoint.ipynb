# %% [markdown]
# # D04 CNN 圖形辨識
#
# Yann LeCun 被譽為 Deep Learning 的三巨頭之一。他的 CNN (Convolutional Neural Networks) 是讓 Neural Network 重新受到重視的主因之一。

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 讀入套件、準備資料
#
# 這裡我們新增一個 `Flatten` layer, 還有 `Conv2D`, `MaxPooling2D`, 使用訓練方式是 `Adadelta`, 這是參考原作的。
#
# [Keras 範例集](https://github.com/fchollet/keras/blob/master/examples)

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# 做 CNN 的時候我們可以直接把矩陣塞進去。不過一張彩色的圖通常有 R, G, B 三個矩陣, 但我們這是灰階只有一個。所以 (28, 28) 的矩陣要變成
#
# * channels_last: (28, 28, 1)
# * channels_first: (1, 28, 28)
#
# 注意很討厭的, 表示法是不一樣的!

# %%
x_train = x_train.reshape(60000, 28, 28, 1)/255
x_test = x_test.reshape(10000, 28, 28, 1)/255
#x_train = x_train.astype("float32")
#x_test = x_test.astype("float32")
#x_train = x_train / 255
#x_test = x_test / 255

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# 確定一下一個訓練輸入長什麼樣子。

# %%
x_train.shape[1:]
# Out:
# (28, 28, 1)

# %% [markdown]
# ## 2. 打造 CNN
#
# CNN filter 一般是「越用越多」, 但要幾次 CNN, 是不是每次都要接 MaxPooling 可以自己決定!

# %%
model = Sequential()

# %% [markdown]
# 注意這是 Keras 2 的寫法。我們這裡要用 10 個 3x3 的 filters。

# %%
model.add(Conv2D(10, (3, 3), padding='same', input_shape=(28,28,1),
                activation='relu'))

# %% [markdown]
# 然後每 2x2 的區域做 MaxPooling。

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
model.add(Conv2D(20, (3, 3), padding='same',
                activation='relu'))

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
model.add(Conv2D(120, (3, 3), padding='same',
                activation='relu'))

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))

# %% [markdown]
# 接著要送進一般的神經網路學了, 我們用一個 hidden layer, 200 個神經元。

# %%
model.add(Flatten())
model.add(Dense(200, activation='relu'))

# %% [markdown]
# 最後輸出用 softmax 處理一下。

# %%
model.add(Dense(10, activation='softmax'))

# %%
model.compile(loss="categorical_crossentropy",
              optimizer=SGD(lr=0.087),
              metrics=['accuracy'])

# %% [markdown]
# ## 3. 訓練和結果

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 10)        100
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 10)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 20)        1820
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 20)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 120)         21720
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 120)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1080)              0
# _________________________________________________________________
# dense (Dense)                (None, 200)               216200
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2010
# =================================================================
# Total params: 241,850
# Trainable params: 241,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, batch_size=128, epochs=12)
# Out:
# Train on 60000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 7s 118us/sample - loss: 0.4069 - accuracy: 0.8696
# Epoch 2/12
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.0837 - accuracy: 0.9733
# Epoch 3/12
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.0602 - accuracy: 0.9810
# Epoch 4/12
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.0458 - accuracy: 0.9855
# Epoch 5/12
# 60000/60000 [==============================] - 7s 112us/sample - loss: 0.0388 - accuracy: 0.9879
# Epoch 6/12
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.0318 - accuracy: 0.9896
# Epoch 7/12
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.0279 - accuracy: 0.9910
# Epoch 8/12
# 60000/60000 [==============================] - 7s 112us/sample - loss: 0.0229 - accuracy: 0.9926
# Epoch 9/12
# 60000/60000 [==============================] - 7s 112us/sample - loss: 0.0205 - accuracy: 0.9931
# Epoch 10/12
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.0174 - accuracy: 0.9947
# Epoch 11/12
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.0158 - accuracy: 0.9950
# Epoch 12/12
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.0135 - accuracy: 0.9956

# %% [markdown]
# ## 3. 看最後分數
#
# 我們把測試資料結果放 result。

# %%
result = model.predict_classes(x_test)

# %% [markdown]
# 隨便看 25 個數字的結果。

# %%
pick = np.random.randint(1,9999, 25)

# %%
plt.subplots_adjust(wspace=0.5, hspace=0.5)
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(x_test[pick[i]].reshape(28,28), cmap='Greys')
    plt.title(result[pick[i]])
    plt.axis("off")

# %% [markdown]
# 看看分數。

# %%
score = model.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
loss, acc = score

# %%
print(acc)
# Out:
# 0.9891

# %%
model.save('myCNNmodel.h5')

# %% [markdown]
# ### 讀回來!

# %%
del model

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('myCNNmodel.h5')

# %%
predict = model.predict_classes(x_test)

# %%
pick = np.random.randint(1,9999, 5)

for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(x_test[pick[i]].reshape(28,28), cmap='Greys')
    plt.title(predict[pick[i]])
    plt.axis("off")
