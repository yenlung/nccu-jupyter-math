# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# ### 1. 讀入 MNSIT 數據集

# %%
from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %% [markdown]
# ### 2. 資料整理

# %% [markdown]
# ### Channel
#
# CNN 要注意一張圖有多少個 channel, 開始我們因為只有灰階, 所以只有一個 channel。因此我們要轉一下我們的資料格式:
#
#     (28,28) --> (28, 28, 1)

# %%
x_train = x_train.reshape(60000, 28, 28, 1) / 255

# %%
x_test = x_test.reshape(10000, 28, 28, 1) / 255

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# ### 3. step 1: 打造函數學習機 (CNN)

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), padding='same',
                input_shape=(28,28,1),
                activation='relu'))

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Conv2D(32, (3,3), padding='same',
                activation='relu'))

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Conv2D(64, (3,3), padding='same',
                activation='relu'))

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Flatten())

# %%
model.add(Dense(54, activation='relu'))

# %%
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# #### 看一下我們的神經網路

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 54)                31158
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                550
# =================================================================
# Total params: 55,004
# Trainable params: 55,004
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### 組裝

# %%
model.compile(loss='mse', optimizer=SGD(lr=0.087),
             metrics=['accuracy'])

# %% [markdown]
# ### 4. step 2: fit

# %%
model.fit(x_train, y_train, batch_size=128, epochs=12)
# Out:
# Train on 60000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 7s 125us/sample - loss: 0.0894 - accuracy: 0.1929
# Epoch 2/12
# 60000/60000 [==============================] - 7s 120us/sample - loss: 0.0873 - accuracy: 0.4046
# Epoch 3/12
# 60000/60000 [==============================] - 7s 120us/sample - loss: 0.0683 - accuracy: 0.5195
# Epoch 4/12
# 60000/60000 [==============================] - 7s 120us/sample - loss: 0.0279 - accuracy: 0.8236
# Epoch 5/12
# 60000/60000 [==============================] - 7s 119us/sample - loss: 0.0165 - accuracy: 0.8945
# Epoch 6/12
# 60000/60000 [==============================] - 7s 120us/sample - loss: 0.0124 - accuracy: 0.9215
# Epoch 7/12
# 60000/60000 [==============================] - 7s 119us/sample - loss: 0.0102 - accuracy: 0.9357
# Epoch 8/12
# 60000/60000 [==============================] - 7s 119us/sample - loss: 0.0087 - accuracy: 0.9453
# Epoch 9/12
# 60000/60000 [==============================] - 7s 120us/sample - loss: 0.0077 - accuracy: 0.9505
# Epoch 10/12
# 60000/60000 [==============================] - 7s 120us/sample - loss: 0.0070 - accuracy: 0.9560
# Epoch 11/12
# 60000/60000 [==============================] - 7s 119us/sample - loss: 0.0065 - accuracy: 0.9588
# Epoch 12/12
# 60000/60000 [==============================] - 7s 120us/sample - loss: 0.0061 - accuracy: 0.9618

# %% [markdown]
# ### Step 3. 預測

# %%
result = model.predict_classes(x_test)

# %% [markdown]
# ### 看看測試資料表現如何

# %%
loss, acc = model.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print(f'測試資料的正確率為 {acc*100:.2f}%')
# Out:
# 測試資料的正確率為 96.60%

# %%
def my_predict(n):
    print('我可愛的 CNN 預測是', result[n])
    X = x_test[n].reshape(28,28)
    plt.imshow(X, cmap='Greys')

# %%
from ipywidgets import interact_manual

# %%
interact_manual(my_predict, n=(0, 9999));
# Out:
# interactive(children=(IntSlider(value=4999, description='n', max=9999), Button(description='Run Interact', sty…
# <function __main__.my_predict(n)>

# %% [markdown]
# ### 把我們的 model 存起來

# %%
model.save('myCNNmodel.h5')
