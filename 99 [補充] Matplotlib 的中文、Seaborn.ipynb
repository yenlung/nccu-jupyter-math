# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl

# %% [markdown]
# 這裡參考 Mosky 在, 比如說[這裡](https://github.com/moskytw/hypothesis-testing-with-python)的做法。
#
# 如果明明有的字型, `matplotlib` 說找不到的話, 有可能需要讓 `matplotlib` 清掉原本的 cache。
#
#     !rm -rf {mpl.get_cachedir()}
#     mpl.font_manager._rebuild()
#
# 記得, 這不是每要做的事, 只有在有新的字型加入後做就可以。

# %% [markdown]
# 另外, 不知道系統有什麼中文字型, 可以打入
#
#     !fc-list :lang=zh family
#
# 另外也可以確認 `matplotlib` 真的「看到的」字型:
#
#     [f.name for f in mpl.font_manager.fontManager.ttflist]

# %%
# mpl.rcParams['font.family'] = 'Noto Sans CJK TC'

# %%
mpl.rc('font', family='Noto Sans CJK TC')

# %% [markdown]
# 使用 Google `Noto Sans CJK TC` 字型, 請到[這裡](https://www.google.com/get/noto/#sans-hant)下載。

# %%
x = np.linspace(-2*np.pi, 2* np.pi, 200)
y = np.sin(x)

# %%
plt.title('$\sin$ 函數的圖形')
plt.plot(x,y)

# %%
import seaborn as sns

# %%
sns.set()

# %%
sns.set(rc={'font.family':'Noto Sans CJK TC'})

# %% [markdown]
# 一般來說, 你只要用
#
#     sns.set()
#
# 之後 `plt.plot` 等就「交給 `seaborn`」管了! 於是你可以再下之前我們的指令!
#
#     mpl.rc('font', family='Noto Sans CJK TC')

# %%
plt.title('$\sin$ 函數的圖形')
plt.plot(x,y)

# %% [markdown]
# ### 回復到原來的 `matplotlib`

# %%
sns.reset_orig()
# Out:
# /Users/yenlung/anaconda3/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The examples.directory rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2. In the future, examples will be found relative to the 'datapath' directory.
#   self[key] = other[key]
# /Users/yenlung/anaconda3/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/yenlung/anaconda3/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
#   self[key] = other[key]
# /Users/yenlung/anaconda3/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/yenlung/anaconda3/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]

# %%
plt.title('$\sin$ 函數的圖形')
plt.plot(x,y)

# %% [markdown]
# ### 不要一路可愛 `xkcd` 風

# %%
with plt.xkcd():
    plt.plot(x,y)

# %%
plt.plot(x,y)
